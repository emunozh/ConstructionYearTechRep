# %% [markdown]
# # The Use of Diffusion Algorithms for the Estimation of Construction Year Within Urban Models
#
# # Annex A: Main document showing the use of the model

# %% [markdown]
# M. Esteban Muñoz H. <marcelo.hidalgo@hcu-hamburg.de> &
# Irene Peters <irene.peters@hcu-hamburg.de>
#
# Technical Urban Infrastructure Systems Group, HafenCity University, Hamburg, Germany

# %% [markdown]
# #Table of Contents
# 1. [Fetch buildings from database](#1.-Fetch-buildings-from-database)
# 2. [Neighbours ranking](#2.-Neighbours-ranking)
# 3. [Diffusion model](#3.-Diffusion-model)

# %% [markdown]
# # 1. Fetch buildings from database

# %% [markdown]
# Fetch data from PostgreSQL database and store it as a hdf file 'data.h5'.

# %%
#from scripts._fetchBuildingsPostgreSQL import _fetchBuildings
#Buildings = _fetchBuildings()

# %%
import pandas as pd
Buildings = pd.read_hdf('data.h5', 'Buildings')

# %%
from scripts.plots import plotByear
# %matplotlib inline

# %%
plotByear(Buildings)

# %%
from scripts.plots import plotBuildings

# %%
plotBuildings(Buildings, legend=False)

# %% [markdown]
# **Figure 2:** Initial state (iter=0) of selected urban area

# %% [markdown]
# # 2. Neighbours ranking

# %%
from scripts._getNeighbours import _getNeighbours
from scripts.plots import plotNeighbours

# %%
from random import choice, seed
seed(12456)
ID = choice(Buildings.index)

# %%
import numpy as np

# %%
N = _getNeighbours(Buildings.loc[ID, "neighbours"], Buildings, ID)

# %%
def fp(x):
    return "{:0.2f}".format(x)

def fi(x):
    return "{:}".format(x[-3:])

def fs(x):
    return "{:}".format(int(x))

N2 = N.ix[0:6]
N2.index = [fi(i) for i in N.ix[0:6].index]
    
with open("../TABLES/neighbours.tex", "w") as table:
    table.write(N2.loc[:,["baw", "gfk", "bja", "sqm",
                         "shell_wall", "distance", "rank"]].to_latex(formatters=[fs, fs, fs, fp, fp, fp , fp, fp]))

# %%
plotNeighbours(Buildings, N, ID)

# %% [markdown]
# **Figure 3:** Ranking of neighbours based on building characteristics and euclidean distance

# %% [markdown]
# # 3. Diffusion model

# %%
from scripts._getByear import _getByear

# %%
Buildings = _getByear(Buildings)
# Out:
# iter =  0
# iter =  1
# iter =  2
# iter =  3
# iter =  4
# iter =  5
# iter =  6

# %% [markdown]
# **Figure 2:** Initial state (iter=0) of selected urban area
